# %% [markdown]
# ## frist program

# %%
import numpy as np
import pandas as pd

# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## delete columns name

# %%
# read plain text file
df_txt = pd.read_csv('C:\\Users\\Admin\\Documents\\PANDS\\dataset\\demo_text.txt')
df_txt
# Out:
#      Unnamed: 0  5.1  3.5  1.4  0.2     Iris-setosa
# 0             0  4.9  3.0  1.4  0.2     Iris-setosa
# 1             1  4.7  3.2  1.3  0.2     Iris-setosa
# 2             2  4.6  3.1  1.5  0.2     Iris-setosa
# 3             3  5.0  3.6  1.4  0.2     Iris-setosa
# 4             4  5.4  3.9  1.7  0.4     Iris-setosa
# ..          ...  ...  ...  ...  ...             ...
# 144         144  6.7  3.0  5.2  2.3  Iris-virginica
# 145         145  6.3  2.5  5.0  1.9  Iris-virginica
# 146         146  6.5  3.0  5.2  2.0  Iris-virginica
# 147         147  6.2  3.4  5.4  2.3  Iris-virginica
# 148         148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 6 columns]

# %% [markdown]
# ### pd install

# %%
! pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
# read excel file
df_excel = pd.read_excel('C:\\Users\\Admin\\Documents\\PANDS\\dataset\\excel_file.xlsx')
df_excel
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status   State_names  \
# 0        3/10/2019          151378  Female   25         Single       Wyoming
# 1         7/2/2019          151751  Female   42         Single      Delaware
# 2        6/14/2019          151689    Male   38        Married       Montana
# 3         8/5/2019          151849    Male   24        Married  Rhode Island
#
#     Segment Employees_status Payment_method  Referal  Amount_spent  \
# 0  Platinum     Unemployment           Card        1       2740.57
# 1     Basic     Unemployment           Card        0        977.80
# 2     Basic          workers         PayPal        1       2978.21
# 3     Basic          workers           Card        1       1157.79
#
#    Transaction_ID.1
# 0            151378
# 1            151751
# 2            151689
# 3            151849

# %% [markdown]
# # 3.1 Data Exploring

# %% [markdown]
# ## Retriving Rows From Data Frame

# %%
# for csv file
df = pd.read_csv('C:\\Users\\Admin\\Documents\\PANDS\\dataset\\online_store_customer_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2356 non-null   float64
#  10  Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %%
# display frist 6 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2356 non-null   float64
#  10  Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %% [markdown]
# ## Display Numbers of Rows and Columns

# %%
# display datatype
df.dtypes
# Out:
# Transaction_date     object
# Transaction_ID        int64
# Gender               object
# Age                 float64
# Marital_status       object
# State_names          object
# Segment              object
# Employees_status     object
# Payment_method       object
# Referal             float64
# Amount_spent        float64
# dtype: object

# %%
df.shape
# Out:
# (2512, 11)

# %%
df.columns
# Out:
# Index(['Transaction_date', 'Transaction_ID', 'Gender', 'Age', 'Marital_status',
#        'State_names', 'Segment', 'Employees_status', 'Payment_method',
#        'Referal', 'Amount_spent'],
#       dtype='object')

# %%
# display Age columns frist 3 rows data
df['Age'].head(3)
# Out:
# 0    19.0
# 1    49.0
# 2    63.0
# Name: Age, dtype: float64

# %%
# display frist 4 rows of age Transaction_data and Gender columns
df[['Age','Transaction_date','Gender']].head(4)
# Out:
#     Age Transaction_date  Gender
# 0  19.0         1/1/2019  Female
# 1  49.0         1/1/2019    Male
# 2  63.0         1/1/2019    Male
# 3  18.0         1/1/2019     NaN

# %%
# display frist 4 rows of age Transaction_data and Gender columns
df[['Age','Transaction_date','Gender']].tail(4)
# Out:
#        Age Transaction_date  Gender
# 2508  36.0         5/1/2021  Female
# 2509  22.0         5/1/2021    Male
# 2510  44.0         5/1/2021     NaN
# 2511  48.0         5/1/2021    Male

# %% [markdown]
# ## Retriving a Range of Rows

# %%
# for display 2nd to 6th rows
df[2:7]
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
# 5         1/3/2019          151205    Male  71.0         Single       Hawaii
# 6         1/3/2019          151206  Female  34.0        Married   New Mexico
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      NaN       1199.79
# 4     Basic    self-employed           Card      0.0           NaN
# 5     Basic        Employees         PayPal      1.0       2922.66
# 6  Platinum        Employees         PayPal      1.0       1481.42

# %%
# for display starting to 10th
df[:11]
# Out:
#    Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0          1/1/2019          151200  Female  19.0         Single       Kansas
# 1          1/1/2019          151201    Male  49.0         Single     Illinois
# 2          1/1/2019          151202    Male  63.0        Married   New Mexico
# 3          1/1/2019          151203     NaN  18.0         Single     Virginia
# 4          1/1/2019          151204    Male  27.0         Single  Connecticut
# 5          1/3/2019          151205    Male  71.0         Single       Hawaii
# 6          1/3/2019          151206  Female  34.0        Married   New Mexico
# 7          1/3/2019          151207    Male  37.0        Married  Connecticut
# 8          1/4/2019          151208    Male  75.0        Married      Florida
# 9          1/4/2019          151209  Female  41.0        Married      Vermont
# 10         1/4/2019          151210  Female  56.0        Married   California
#
# ...

# %%
# for display last two rows
df[-2:]
# Out:
#      Transaction_date  Transaction_ID Gender   Age Marital_status State_names  \
# 2510         5/1/2021          153698    NaN  44.0         Single    New York
# 2511         5/1/2021          153699   Male  48.0         Single  California
#
#      Segment Employees_status Payment_method  Referal  Amount_spent
# 2510   Basic        Employees         PayPal      0.0       1909.77
# 2511  Silver          workers         PayPal      1.0       1073.15

# %% [markdown]
# # 3.2 Data Cleaning

# %% [markdown]
# #### After the explore our dataset may need  to clean them for better analysis. data coming in from multiple section in same values . this is where data cleaning becomes extremly importance in this section we will delete unwanted data to correct appropriate data type etc. data cleaning is the process of preparing data for analysis /ML/DL by removing or modifiying data that is incorrect ,incomplate ,irrelevant , duplicated or improperly formatted.

# %% [markdown]
# ## Delete Column Names

# %%
# Drop unwanted columns 
df.drop(['Transaction_ID'],axis=1, inplace = True)

# %%
df
# Out:
#      Transaction_date  Gender   Age Marital_status     State_names   Segment  \
# 0            1/1/2019  Female  19.0         Single          Kansas     Basic
# 1            1/1/2019    Male  49.0         Single        Illinois     Basic
# 2            1/1/2019    Male  63.0        Married      New Mexico     Basic
# 3            1/1/2019     NaN  18.0         Single        Virginia  Platinum
# 4            1/1/2019    Male  27.0         Single     Connecticut     Basic
# ...               ...     ...   ...            ...             ...       ...
# 2507         5/1/2021  Female  57.0         Single  South Carolina  Platinum
# 2508         5/1/2021  Female  36.0        Married          Hawaii    Silver
# 2509         5/1/2021    Male  22.0         Single  South Carolina     Basic
# 2510         5/1/2021     NaN  44.0         Single        New York     Basic
# 2511         5/1/2021    Male  48.0         Single      California    Silver
#
# ...

# %% [markdown]
# ## Change Column Name

# %%
# Create new df_col dataframe df.copy() method 
df_col = df.copy()
df_col
# Out:
#      Transaction_date  Gender   Age Marital_status     State_names   Segment  \
# 0            1/1/2019  Female  19.0         Single          Kansas     Basic
# 1            1/1/2019    Male  49.0         Single        Illinois     Basic
# 2            1/1/2019    Male  63.0        Married      New Mexico     Basic
# 3            1/1/2019     NaN  18.0         Single        Virginia  Platinum
# 4            1/1/2019    Male  27.0         Single     Connecticut     Basic
# ...               ...     ...   ...            ...             ...       ...
# 2507         5/1/2021  Female  57.0         Single  South Carolina  Platinum
# 2508         5/1/2021  Female  36.0        Married          Hawaii    Silver
# 2509         5/1/2021    Male  22.0         Single  South Carolina     Basic
# 2510         5/1/2021     NaN  44.0         Single        New York     Basic
# 2511         5/1/2021    Male  48.0         Single      California    Silver
#
# ...

# %%
# rename columns name
df_col.rename(columns={"Transaction_date":" date","Gender":"sex"}, inplace=True)
df_col.head(3)
# Out:
#        date     sex   Age Marital_status State_names Segment Employees_status  \
# 0  1/1/2019  Female  19.0         Single      Kansas   Basic     Unemployment
# 1  1/1/2019    Male  49.0         Single    Illinois   Basic    self-employed
# 2  1/1/2019    Male  63.0        Married  New Mexico   Basic          workers
#
#   Payment_method  Referal  Amount_spent
# 0          Other      1.0       2051.36
# 1           Card      0.0        544.04
# 2         PayPal      1.0       1572.60

# %% [markdown]
# ## String Values Change or replace

# %%
df_col.head(3)
# Out:
#        date     sex   Age Marital_status State_names Segment Employees_status  \
# 0  1/1/2019  Female  19.0         Single      Kansas   Basic     Unemployment
# 1  1/1/2019    Male  49.0         Single    Illinois   Basic    self-employed
# 2  1/1/2019    Male  63.0        Married  New Mexico   Basic          workers
#
#   Payment_method  Referal  Amount_spent
# 0          Other      1.0       2051.36
# 1           Card      0.0        544.04
# 2         PayPal      1.0       1572.60

# %%
# changing female to woman and male to man in sex column.
# frist argument in loc function is condition and secound one is columns name.
df_col.loc[df_col.sex == "Female " ,'sex'] = 'woman'
df_col.loc[df_col.sex == "Female " ,'sex'] = 'man'

# %% [markdown]
# # Datatype Change

# %%
df_col.info
# Out:
# <bound method DataFrame.info of           date     sex   Age Marital_status     State_names   Segment  \
# 0     1/1/2019  Female  19.0         Single          Kansas     Basic
# 1     1/1/2019    Male  49.0         Single        Illinois     Basic
# 2     1/1/2019    Male  63.0        Married      New Mexico     Basic
# 3     1/1/2019     NaN  18.0         Single        Virginia  Platinum
# 4     1/1/2019    Male  27.0         Single     Connecticut     Basic
# ...        ...     ...   ...            ...             ...       ...
# 2507  5/1/2021  Female  57.0         Single  South Carolina  Platinum
# 2508  5/1/2021  Female  36.0        Married          Hawaii    Silver
# 2509  5/1/2021    Male  22.0         Single  South Carolina     Basic
# 2510  5/1/2021     NaN  44.0         Single        New York     Basic
# 2511  5/1/2021    Male  48.0         Single      California    Silver
#
#      Employees_status Payment_method  Referal  Amount_spent
# ...

# %%
print(df_col.columns)
# Out:
# Index([' date', 'sex', 'Age', 'Marital_status', 'State_names', 'Segment',
#        'Employees_status', 'Payment_method', 'Referal', 'Amount_spent'],
#       dtype='object')

# %%
# change object type to datafim64 format
df_col[' date'] = df_col[' date'].astype('datetime64[ns]')

# %%
print(df_col.columns)
# Out:
# Index([' date', 'sex', 'Age', 'Marital_status', 'State_names', 'Segment',
#        'Employees_status', 'Payment_method', 'Referal', 'Amount_spent'],
#       dtype='object')

# %%
# change object type to datafim64 format
df_col[' date'] = df_col[' date'].astype('datetime64[ns]')

# %%
# change folat64 to float32 of referal columns
df_col['Referal'] = df_col['Referal'].astype('float32')

# %%
# duplicat rows display keep argument will --- ' frist ' , ' last ' and false 
duplicate_values = df.duplicated(keep='first')
duplicate_values
#df.loc[duplicate_values, :]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2507    False
# 2508    False
# 2509    False
# 2510    False
# 2511    False
# Length: 2512, dtype: bool

# %%
df_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0    date             2512 non-null   datetime64[ns]
#  1   sex               2484 non-null   object
#  2   Age               2470 non-null   float64
#  3   Marital_status    2512 non-null   object
#  4   State_names       2512 non-null   object
#  5   Segment           2512 non-null   object
#  6   Employees_status  2486 non-null   object
#  7   Payment_method    2512 non-null   object
#  8   Referal           2356 non-null   float32
#  9   Amount_spent      2270 non-null   float64
# dtypes: datetime64[ns](1), float32(1), float64(2), object(6)
# memory usage: 186.6+ KB

# %% [markdown]
# # 3.4 Handling Missing Values

# %% [markdown]
# #### handling missing values in the common task in the data pre-processing part for many reason encounter missing values without dealing with this we cant do this proper model building for this section first will out missing values then we decide how to handle then we can handle

# %% [markdown]
# ## Display Missing Values Information

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\Admin\\Documents\\PANDS\\dataset\\online_store_customer_data.csv')
df.head(10)
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
# 5         1/3/2019          151205    Male  71.0         Single       Hawaii
# 6         1/3/2019          151206  Female  34.0        Married   New Mexico
# 7         1/3/2019          151207    Male  37.0        Married  Connecticut
# 8         1/4/2019          151208    Male  75.0        Married      Florida
# 9         1/4/2019          151209  Female  41.0        Married      Vermont
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Amount_spent        242
# Referal             156
# Age                  42
# Gender               28
# Employees_status     26
# Transaction_date      0
# Transaction_ID        0
# Marital_status        0
# State_names           0
# Segment               0
# Payment_method        0
# dtype: int64

# %%
df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %% [markdown]
# ## Delete nun rows

# %% [markdown]
# #### if we have less nun values then we can delete entire 1

# %%
# df copy to df_copy
df_new = df.copy()

# %%
df_new
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo

# %%
# fetch dataset
heart_disease = fetch_ucirepo(id=45)

# %%
# data (as pandas dataframes)
x = heart_disease.data.features
y = heart_disease.data.targets

# %%
# metadata
print(heart_disease.metadata)
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %% [markdown]
# ## impute missing values

# %%
# variable information 
print(heart_disease)
# Out:
# {'data': {'ids': None, 'features':      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal
# 0        3  0.0   6.0
# ...

# %% [markdown]
# ### sametimes if we delete entire columns that will be not the approprite apporach . delete columns can affect our model buliding we will lose our main fetures . for imputing we have many approches so here same of the most popular techiques

# %% [markdown]
# ### Method 1 - impute fixed value like 0 , 'Unknown ' or 'missing ' etc . we inpute unkown in gender columns.

# %%
df['Gender'].fillna('unknown', inplace=True)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15736\208596268.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna('unknown', inplace=True)
#      Transaction_date  Transaction_ID   Gender   Age Marital_status  \
# 0            1/1/2019          151200   Female  19.0         Single
# 1            1/1/2019          151201     Male  49.0         Single
# 2            1/1/2019          151202     Male  63.0        Married
# 3            1/1/2019          151203  unknown  18.0         Single
# ...

# %% [markdown]
# ## method 2 - impute Mean ,Median and mode

# %%
# impute mean in amount _spent columns 
mean_amount_spent = df['Amount_spent'].mean()
df['Amount_spent'].fillna(mean_amount_spent, inplace=True)
df
mean_amount_spent
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15736\701147130.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Amount_spent'].fillna(mean_amount_spent, inplace=True)
# 1418.4225770925111

# %%
# Impute median in age column
median_Age = df['Age'].median()
df['Age'].fillna(median_Age, inplace=True)
df
median_Age
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15736\367910255.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(median_Age, inplace=True)
# 47.0

# %%
# impute mode in Employees_status columns
mode_emp = df['Employees_status'].mode().iloc[0]
df['Employees_status'].fillna(mode_emp, inplace=True)
mode_emp
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15736\2397687048.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Employees_status'].fillna(mode_emp, inplace=True)
# 'Employees'

# %%
mean_amount_spent
# Out:
# 1418.4225770925111

# %%
mode_emp
# Out:
# 'Employees'

# %% [markdown]
# ### method 3 - imputing forward fill or backfill by ffill and bfill.in ffill missing value impute from the value of the above row and for bfill .it's taken the below rows value.

# %%
df['Referal'].fillna(method='ffill', inplace=True)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15736\1967400654.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Referal'].fillna(method='ffill', inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15736\1967400654.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Referal'].fillna(method='ffill', inplace=True)
#      Transaction_date  Transaction_ID   Gender   Age Marital_status  \
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Transaction_date    0
# Transaction_ID      0
# Gender              0
# Age                 0
# Marital_status      0
# State_names         0
# Segment             0
# Employees_status    0
# Payment_method      0
# Referal             0
# Amount_spent        0
# dtype: int64

# %% [markdown]
# # 4 Memory Management

# %% [markdown]
# #### when we on large datasets,there we get one big issue is a memory problem.We need too large resources for dealing with this . but there are same methodes in pands to dael with this here are same methods or strategies to deal with this problem with help of pands

# %%
df_memory = df.copy()

# %%
df_usage = df_memory.memory_usage(deep=True)
memory_usage_in_mbs = round(np.sum(memory_usage /1024 ** 2), 3)
print(f" Total memory taking df_memory dataframe is : {memory _usage_in_mbs:.2f} MB ")
# Out:
#   Cell In[56], line 3
#     print(f" Total memory taking df_memory dataframe is : {memory _usage_in_mbs:.2f} MB ")
#                                                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ## chnage oject to category datatypes

# %% [markdown]
# #### our data frame is samll in size . which is 1.15 MB now we will convert our object datatype to category

# %%
# object datatype to category convert
df_memory[df_memory.select_dtypes(['object']).columns] = df_memory.select_dtype(['object']).apply(1ambda x: x.astype('category'))
df_memory

# %%
# convert object to category
df_memory.info(memory_usage="deep")

# %% [markdown]
# ## change int64 or folat64 to int 32,16, or 8

# %% [markdown]
# ### by default panadas stroe numeric values into int64 or folt64. which takes more memory . if we have to store small numbers then we can change to 64 to 32, 16 and so on .for example, our referal columns have only 0 and 1 values so for that we don't need to store at folt64. so now we change it to float 16

# %%
# change Referal columns datatypes
df_memory['Referal'] = df_memory['Referal'],astype('float32')

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # 5.1 calculating basic statisitical measurement

# %%
df.describe().T

# %% [markdown]
# ### we have already above code will display only numeric columns basic statistical information . for object or category columns we can use describe(include=object).

# %%
df.describe(include=object).T

# %% [markdown]
# ### We can caluclate the mean , median ,mode ,maimum values,minimum values-----

# %%
# calculate standard deviation
std = df['Age'].std()

#calculate Minimum values
minimum = df['Age'].min()

#calculate maximum values
maximum = df.Age.max()



print(f" standard deviation of age :{std:.2f}")
print(f" Maximum of Age :{maximum}")
print(f" Minimum of Age :{minimum}")

# %% [markdown]
# # 5.2 Basic bulit in function for data analysis

# %% [markdown]
# ### number of uniqe values in category column

# %%
# for display how many unique values are there in state_names column
df['State_names'].nunique()

# %% [markdown]
# ## Counts of unique values

# %%
df['State_names'].value_counts().T

# %% [markdown]
# ### if we want to show with the percentage of occurrence rather number then we use normalize=True argument in value_counts() function

# %%
# calculate percentage of each category
df['State_names'].value_counts(normalize=True)

# %%
df['State_names'].value_counts().sort_values(ascending = False).head(20)

# %%
# sort  values Amount_spent with ascending order
df.sort_values(by=['Amount_spent']).head(5)

# %% [markdown]
# #### for sorting our dataframe by Amount_spent with descending order.

# %%
# sort  values Amount_spent with  descending a order
df.sort_values(by=['Amount_spent']).tail(5)

# %%
# nlargest
df.nlargest(4, 'Amount_spent').head(3) # first argument is how many rows you want to display and secound one is columns

# %%
# nsmallest
df.nsmallest(4, 'Amount_spent').head(3) # first argument is how many rows you want to display and secound one is columns

# %% [markdown]
# ## Conditional queries on Data

# %%
# filtering - only show Paypal users
condition = df['Payment_method'] == 'PayPal'
df[condition].head()

# %% [markdown]
# ### we can apply multiple conditional queries like before for example , if we want to display all Married Female people who lived in new York then we use thefollowing

# %%
# first create 3 condition
female_person =  df['Gender'] == 'Female'
married_person = df['Marital_status'] == 'Married'
loc_newyork = df['State_names'] == 'New York'

# we passing condition on our dataframe
df[female_person & married_person & loc_newyork].head()

# %% [markdown]
# # 5.3 Summarizing or grouping data

# %% [markdown]
# ## groupby

# %% [markdown]
# ### grouping by one columns : for eaxample ,if we want to find maximum values of age and amount _spent by gender then we can usen this

# %%
df[['Age','Amount_spent']].groupby(df['Gender']).max()

# %% [markdown]
# ### to find mean , count and max value of age and amount_spent by gender then we can use age() function with groupby()

# %%
# Group by one columns
state_gender_res = df[['Age', 'Gender' , 'Amount_spent']].groupby(['Gender']).agg(['count','mean','max'])
state_gender_res

# %% [markdown]
# ### grouping by multiple columns : to find total count,maximum and minimum values of Amount_spent by State_names, gender , and Payment _nethod then we can pass these columns names under groupby () function and add .agg() with count , mean, argument

# %%
# Group by multiple columns
state_gender_res = df[['State_names','Gender','Payment_method','Amount_spent']].groupby([ 'State_names','Gender', 'Payment_method']).agg(['count', 'min', 'max'])
state_gender_res.head(12)

# %% [markdown]
# ## Cross Tabulation(Crosstab)

# %% [markdown]
# ### for creating a simple crosstab between Maritatal_status and Payment_method columns we just use crosstab () with both columns names.

# %%
pd.crosstab(df.Payment_method, df.Gender)

# %%
pd.crosstab(df.Marital_status, df.Payment_method,margins=True, margins_name="Total")

# %%
pd.crosstab(df.Marital_status, df.Payment_method, normalize=True, margins=True, margins_name="Total")
